# %% [markdown]
# ### Exercício 02 – Manipulando dados com Pandas
#
# 'a) Crie um programa em pandas para ler o arquivo em Excel imobiliária.xlsx
# b) e coloque em um dataframe.
# c) Visualize o cabeçalho dos dados;
# d) Visualize as últimas linhas;
# e) Escreva um programa para renomear o cabeçalho da tabela com os
# f) seguintes nomes:
# g) 5. Quais são os tipos de dados que temos no dataframe?
# h) 6. Há valores faltantes ou nulos?
# i) 7. Calcule a soma, média, máximo, mínimo e contagem da coluna Preço.
# j) 8. Crie um programa para criar um dataframe para mostrar as vendas por
# k) região, e salvar um arquivo em Excel para cada região.
# l) Gere um arquivo em Excel para representar as vendas efetuadas pela filial norte
# em 2010.
# m) Gere um arquivo em Excel para representar as vendas efetuadas pela filial
# Sudeste em 2010. Sendo que no relatório deve conter apenas vendas de casas
# sem garagem.
# n) Qual o valor máximo de comissão que a imobiliária numa venda?
# o) Quantas casas de 2 ou 3 dormitórios foram vendidas pelo Ricardo antes de 2011.'

# %%
##A) e B) IMPORTAR O ARQUIVO E COLOCAR EM UM DATAFRAME 
## a) Crie um programa em pandas para ler o arquivo em Excel imobiliária.xlsx
## b) e coloque em um dataframe.

import pandas as pd

df = pd.read_excel("C:\\Users\\CT Desenvolvimento\\Documents\\fundamentosbigData-Python-SENAI\\mike-ferreira-python\\Arquivos\\Imobiliária.xlsx")

# %%
## C) CABEÇALHO
## c) Visualize o cabeçalho dos dados;


df.head()
# Out:
#    Coluna 1  Coluna 2   Coluna 3     Coluna 4  Coluna 5  Coluna 6  Coluna 7  \
# 0    Centro    Simone 2005-10-08  Apartamento     102.5         2         2
# 1  Noroeste    Simone 2005-10-08  Apartamento     199.5         4         4
# 2     Norte   Roberto 2005-10-12         Casa     145.5         2         2
# 3   Sudeste    Simone 2005-10-14  Apartamento     153.5         3         2
# 4  Noroeste  Cristina 2005-10-16  Apartamento      93.0         2         2
#
#   Coluna 8  Coluna 8.1  Coluna 10
# 0      Sim      235500     3532.5
# 1      Não      377700     5665.5
# 2      Não      232500     3487.5
# 3      Não      289100     4336.5
# 4      Sim      235400     3531.0

# %%
## D) ULTIMAS LINHAS
##d) Visualize as últimas linhas;

df.tail()
# Out:
#      Coluna 1     Coluna 2   Coluna 3     Coluna 4  Coluna 5  Coluna 6  \
# 1112  Sudeste     Cristina 2011-03-19  Apartamento      87.5         2
# 1113  Sudeste       Simone 2011-03-20  Apartamento      74.5         2
# 1114    Norte  João Carlos 2011-03-21  Apartamento     192.0         4
# 1115    Leste       Simone 2011-03-27  Apartamento      42.0         1
# 1116    Oeste       Simone 2011-03-28  Apartamento     100.5         2
#
#       Coluna 7 Coluna 8  Coluna 8.1  Coluna 10
# 1112         0      Não      221500     3322.5
# 1113         2      Não      224400     3366.0
# 1114         4      Não      361000     5415.0
# 1115         1      Sim      167900     2518.5
# 1116         2      Sim      227600     3414.0

# %%
##e) Escreva um programa para renomear o cabeçalho da tabela com os
##f) seguintes nomes:

df.columns=(['Filial', 'Vendedor', "Data", 'Tipo', 'Área (m²)', 'Dorms.', 'Garag', 'Piscina', 'Preço', 'Comissão'])
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Filial, Vendedor, Data, Tipo, Área (m²), Dorms., Garag, Piscina, Preço, Comissão]
# Index: []

# %%
## g) 5. Quais são os tipos de dados que temos no dataframe?
## h) 6. Há valores faltantes ou nulos?

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117 entries, 0 to 1116
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Filial     1117 non-null   object
#  1   Vendedor   1117 non-null   object
#  2   Data       1117 non-null   datetime64[ns]
#  3   Tipo       1117 non-null   object
#  4   Área (m²)  1117 non-null   float64
#  5   Dorms.     1117 non-null   int64
#  6   Garag      1117 non-null   int64
#  7   Piscina    1117 non-null   object
#  8   Preço      1117 non-null   int64
#  9   Comissão   1117 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 87.4+ KB

# %%
### i) 7. Calcule a soma, média, máximo, mínimo e contagem da coluna Preço.
#Soma
print(f'A soma resulta no valor de: {df["Preço"].sum()}')

#Média
print(f'O valor médio é: {df["Preço"].mean()}')

#Máximo
print(f'O maior valor é: {df["Preço"].max()}')

#Mínimo
print(f'O menor valor é: {df["Preço"].min()}')

#Contagem
print(f'Existem {df["Preço"].min()} itens na coluna preço')
# Out:
# A soma resulta no valor de: 295035000
# O valor médio é: 264131.6025067144
# O maior valor é: 384300
# O menor valor é: 145100
# Existem 145100 itens na coluna preço

# %%
### j) 8. Crie um programa para criar um dataframe para mostrar as vendas por
## k) região, e salvar um arquivo em Excel para cada região.



df_final = df[df['Filial'] == 'Centro']

#MAPEAMENTO DE CAMINHO E NOME DO ARQUIVO

caminhosaida = "C:\\Users\\CT Desenvolvimento\\Documents\\fundamentosbigData-Python-SENAI\\mike-ferreira-python\\Arquivos\\Relatórios Filiais\\"

arquivo = "centro.xlsx"

df_final.to_excel(caminhosaida + arquivo)

# %%
### Relatório para região Noroeste


df_final = df[df["Filial"] == "Noroeste"]

### Mapeamento de caminho

caminhosaida2 = "C:\\Users\\CT Desenvolvimento\\Documents\\fundamentosbigData-Python-SENAI\\mike-ferreira-python\\arquivos\\Relatórios Filiais\\"

arquivo = "noroeste.xlsx"

## Salvando arquivo em excel

df_final.to_excel(caminhosaida2 + arquivo)

# %%
### Relatório para região Norte


df_final = df[df["Filial"] == "Norte"]

### Mapeamento de caminho

caminhosaida3 = "C:\\Users\\CT Desenvolvimento\\Documents\\fundamentosbigData-Python-SENAI\\mike-ferreira-python\\arquivos\\Relatórios Filiais\\"

arquivo = "norte.xlsx"

## Salvando arquivo em excel

df_final.to_excel(caminhosaida3 + arquivo)

# %%
### Relatório para região Sudeste


df_final = df[df["Filial"] == "Sudeste"]

### Mapeamento de caminho

caminhosaida4 = "C:\\Users\\CT Desenvolvimento\\Documents\\fundamentosbigData-Python-SENAI\\mike-ferreira-python\\arquivos\\Relatórios Filiais\\"

arquivo = "sudeste.xlsx"

## Salvando arquivo em excel

df_final.to_excel(caminhosaida4 + arquivo)

# %%
### Relatório para região Leste


df_final = df[df["Filial"] == "Leste"]

### Mapeamento de caminho

caminhosaida5 = "C:\\Users\\CT Desenvolvimento\\Documents\\fundamentosbigData-Python-SENAI\\mike-ferreira-python\\arquivos\\Relatórios Filiais\\"

arquivo = "leste.xlsx"

## Salvando arquivo em excel

df_final.to_excel(caminhosaida5 + arquivo)

# %%
### Relatório para região Oeeste


df_final = df[df["Filial"] == "Oeeste"]

### Mapeamento de caminho

caminhosaida6 = "C:\\Users\\CT Desenvolvimento\\Documents\\fundamentosbigData-Python-SENAI\\mike-ferreira-python\\arquivos\\Relatórios Filiais\\"

arquivo = "oeste.xlsx"

## Salvando arquivo em excel

df_final.to_excel(caminhosaida6 + arquivo)

# %% [markdown]
# ### l) Gere um arquivo em Excel para representar as vendas efetuadas pela filial norte em 2010.

# %%
### Relatório para região Norte em 2010

df_final = df[(df["Filial"] == "Norte") & (df["Data"]>="2010-01-01") & (df["Data"]<="2010-12-31")]

### Mapeamento de caminho

caminhosaida7 = "C:\\Users\\CT Desenvolvimento\\Documents\\fundamentosbigData-Python-SENAI\\mike-ferreira-python\\arquivos\\Relatórios Filiais\\"

arquivo = "norte2010.xlsx"

## Salvando arquivo em excel

df_final.to_excel(caminhosaida7 + arquivo)

# %% [markdown]
# ### m) Gere um arquivo em Excel para representar as vendas efetuadas pela filial Sudeste em 2010. Sendo que no relatório deve conter apenas vendas de casas sem garagem.

# %%
### Relatório para região Norte em 2010

df_finalm = df[(df["Filial"] == "Sudeste") & (df["Data"]>="2010-01-01") & (df["Data"]<="2010-12-31") & (df["Garag"]== 0) & (df["Tipo"]== 'Casa') ]

print (df_finalm)

### Mapeamento de caminho

caminhosaida9 = "C:\\Users\\CT Desenvolvimento\\Documents\\fundamentosbigData-Python-SENAI\\mike-ferreira-python\\arquivos\\Relatórios Filiais\\"

arquivo = "sudeste2010casasemgaragem.xlsx"

## Salvando arquivo em excel

df_finalm.to_excel(caminhosaida9 + arquivo)
# Out:
#       Filial     Vendedor       Data  Tipo  Área (m²)  Dorms.  Garag Piscina  \
# 924  Sudeste      Adriana 2010-04-12  Casa       31.0       1      0     Não
# 938  Sudeste       Simone 2010-05-09  Casa       71.5       1      0     Não
# 977  Sudeste  João Carlos 2010-07-29  Casa       60.5       1      0     Não
#
#       Preço  Comissão
# 924  159300    2389.5
# 938  150300    2254.5
# 977  156900    2353.5

# %% [markdown]
# ### n) Qual o valor máximo de comissão que a imobiliária numa venda?

# %%
#Máximo
print(f'O maior valor de comissão foi: R$ {df["Comissão"].max()}')


## Mostrar qual foi o maior valor de comissão pago pela imobiliaria e todas as informações da venda

df[df["Comissão"] == df["Comissão"].max()]
# Out:
# O maior valor de comissão foi: R$ 5764.5
#     Filial Vendedor       Data         Tipo  Área (m²)  Dorms.  Garag Piscina  \
# 848    Sul  Adriana 2009-12-27  Apartamento      188.5       4      4     Sim
#
#       Preço  Comissão
# 848  384300    5764.5

# %% [markdown]
# ### o) Quantas casas de 2 ou 3 dormitórios foram vendidas pelo Ricardo antes de 2011.

# %%
### Relatório para região Vendas de Casa do Ricardo até 2011

           
df_final = df[(df["Vendedor"] == "Ricardo") & (df["Data"]<="2010-12-31") & (df["Tipo"]=="Casa") & ((df["Dorms."]==2) | (df["Dorms."]==3))]

print(df_final)

### Mapeamento de caminho

caminhosaida10 = "C:\\Users\\CT Desenvolvimento\\Documents\\fundamentosbigData-Python-SENAI\\mike-ferreira-python\\arquivos\\Relatórios Filiais\\"

arquivo = "ricardo2e3dormate2011.xlsx"

## Salvando arquivo em excel

df_final.to_excel(caminhosaida10 + arquivo)
# Out:
#         Filial Vendedor       Data  Tipo  Área (m²)  Dorms.  Garag Piscina  \
# 82       Norte  Ricardo 2006-02-28  Casa      153.0       3      3     Sim
# 100      Oeste  Ricardo 2006-04-08  Casa      146.5       3      3     Sim
# 156     Centro  Ricardo 2006-07-12  Casa      105.5       2      1     Não
# 171      Norte  Ricardo 2006-07-27  Casa      104.0       2      1     Não
# 184      Leste  Ricardo 2006-08-30  Casa      144.5       3      3     Não
# 200   Noroeste  Ricardo 2006-09-25  Casa      148.5       3      3     Não
# 206        Sul  Ricardo 2006-10-02  Casa      185.0       3      2     Não
# 214      Leste  Ricardo 2006-10-16  Casa      149.5       3      3     Não
# 251   Noroeste  Ricardo 2006-12-13  Casa      109.5       2      2     Sim
# 263   Noroeste  Ricardo 2006-12-29  Casa      101.5       2      0     Não
# 278   Nordeste  Ricardo 2007-01-28  Casa      124.5       2      0     Não
# ...
