# %% [markdown]
# Exercício 01 – Manipulando dataframes com Pandas.
# a) Abra o arquivo world_happiness_report_2015.csv e o aloque em um dataframe.
# b) Verifique o cabeçalho e o final do dataframe.
# c) Quais as colunas desse dataframe?
# d) Quais os tipos de dados temos no dataframe?
# e) Há valores faltantes ou nulos? Em quais colunas?
# f) Renomeie as variáveis como segue:
# g) Quais os valores médios de expect_vida? E o valor mediano? E o máximo da
# variável PIB?

# %%
### Importar a biblioteca carregar o arquivo e alocalo em um dataframe

## a) ABRIR ARQUIVO

import pandas as pd

caminho01 = "C:\\Users\\FIC\\Documents\\mike-ferreira-python\\Arquivos\\world_happiness_report_2015.csv"

df = pd.read_csv(caminho01)

## b) CABEÇALHO E FINAL

df.head()
df.tail()
# Out:
#      country                           region  happiness rank  \
# 159   Rwanda               Sub-Saharan Africa             154
# 160    Benin               Sub-Saharan Africa             155
# 161    Syria  Middle East and Northern Africa             156
# 162  Burundi               Sub-Saharan Africa             157
# 163     Togo               Sub-Saharan Africa             158
#
#      happiness score  standard error  economy (GDP per Capita)   family  \
# 159            3.465         0.03464                   0.22208  0.77370
# 160            3.340             NaN                   0.28665  0.35386
# 161            3.006         0.05015                   0.66320  0.47489
# 162            2.905         0.08658                   0.01530  0.41587
# 163            2.839         0.06727                   0.20868  0.13995
#
#      health (Life Expectancy)  freedom  trust (Government Corruption)  \
# 159                   0.42864  0.59201                        0.55191
# ...

# %%
## c) d) e e) COLUNAS, TIPOS DE DADOS E VALORES NULOS

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   contry             164 non-null    object
#  1   region             164 non-null    object
#  2   rank_felicidade    164 non-null    int64
#  3   score_felicidade   156 non-null    float64
#  4   standard_error     163 non-null    float64
#  5   PIB                164 non-null    float64
#  6   family             164 non-null    float64
#  7   expect_vida        164 non-null    float64
#  8   freedom            164 non-null    float64
#  9   corrupção          164 non-null    float64
#  10  generosity         164 non-null    float64
#  11  dystopia residual  150 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 15.5+ KB

# %%
## f) Renomeando as colunas


df.columns=['contry','region','rank_felicidade','score_felicidade','standard_error','PIB','family','expect_vida','freedom','corrupção','generosity','dystopia residual']

df.head()
# Out:
#         contry          region  rank_felicidade  score_felicidade  \
# 0  Switzerland  Western Europe                1             7.587
# 1      Iceland  Western Europe                2             7.561
# 2      Denmark  Western Europe                3             7.527
# 3       Norway  Western Europe                4             7.522
# 4       Canada   North America                5             7.427
#
#    standard_error      PIB   family  expect_vida  freedom  corrupção  \
# 0         0.03411  1.39651  1.34951      0.94143  0.66557    0.41978
# 1         0.04884  1.30232  1.40223      0.94784  0.62877    0.14145
# 2         0.03328  1.32548  1.36058      0.87464  0.64938    0.48357
# 3         0.03880  1.45900  1.33095      0.88521  0.66973    0.36503
# 4         0.03553  1.32629  1.32261      0.90563  0.63297    0.32957
#
#    generosity  dystopia residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# ...

# %%
## g) Quais os valores médios de expect_vida? E o valor mediano? E o máximo da variável PIB?

df.describe()
# Out:
#        rank_felicidade  score_felicidade  standard_error         PIB  \
# count       164.000000        156.000000      163.000000  164.000000
# mean         77.018293          5.424487        0.047692    0.862023
# std          46.699860          1.212568        0.017110    0.404519
# min           1.000000          2.000000        0.018480    0.000000
# 25%          35.750000          4.561250        0.036780    0.579618
# 50%          76.500000          5.260500        0.043940    0.920510
# 75%         117.250000          6.422000        0.052335    1.190585
# max         158.000000          7.587000        0.136930    1.690420
#
#            family  expect_vida     freedom   corrupção  generosity  \
# count  164.000000   164.000000  164.000000  164.000000  164.000000
# mean     1.000812     0.638187    0.434959    0.149978    0.239615
# std      0.272449     0.246327    0.152201    0.124201    0.128053
# min      0.000000     0.000000    0.000000    0.000000    0.000000
# ...
