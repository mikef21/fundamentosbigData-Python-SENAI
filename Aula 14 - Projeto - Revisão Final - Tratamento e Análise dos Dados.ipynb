# %% [markdown]
# ![](attachment:image.png)

# %%
# Importando bibliotecas

import pandas as pd

import numpy as np

import seaborn as sbs

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

import os

# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Carregando arquivos de Vendas

caminhopasta = './arquivos/vendas/'

os.listdir(caminhopasta)


# Lista Vazia

diretorios = []

#Laço de repetição

for file in os.listdir(caminhopasta):

    if file.endswith('.xlsx'):
      
      diretorios.append(caminhopasta + file)

diretorios

# Criar dataframe vazio

df_final = pd.DataFrame()

# Abrir os documentos e agrupar em um unico dataframe

for path in diretorios:
    df = pd.read_excel(path)
    df_final = pd.concat([df_final,df])

df_final.to_csv('./arquivos/arquivocombinado.csv')

# %%
# Carregando arquivos de Vendas

caminhopasta = './arquivos/vendas/'

os.listdir(caminhopasta)


# Lista Vazia

diretorios = []

#Laço de repetição

for file in os.listdir(caminhopasta):

    if file.endswith('.xlsx'):
      
      diretorios.append(caminhopasta + file)

diretorios

# Criar dataframe vazio

df_final = pd.DataFrame()

# Abrir os documentos e agrupar em um unico dataframe

for path in diretorios:
    df = pd.read_excel(path)
    df_final = pd.concat([df_final,df])

df_final.to_csv('./arquivos/arquivocombinado.csv')

# %%
# Carregando arquivos de Dimensões

caminhod = "C:\\Users\\FIC\\Documents\\mike-ferreira-python\\Desafio Python - Mike\\arquivos\\Dimensões.xlsx"

dfcliente = pd.read_excel((caminhod), sheet_name = 'Cliente')

dfproduto = pd.read_excel((caminhod), sheet_name = 'Produto')

dfgrupoproduto = pd.read_excel((caminhod), sheet_name = 'GrupoProduto')

dfvendedor = pd.read_excel((caminhod), sheet_name = 'Vendedor')

dfdata = pd.read_excel((caminhod), sheet_name = 'Data')

# %%
# Carregando arquivo de base-meta-new 

caminhometas='./arquivos/base-meta-new.xlsx'

dfmetas = pd.read_excel(caminhometas)

dfmetas = dfmetas.iloc[3:,1:]

#RESETAR O INDICE DO DATAFRAME

dfmetas = dfmetas.reset_index(0,                 # Inicio do Indice
                              drop=True          # Remove coluna existente de indice
                              )


#RENOMEAR AS COLUNAS DO DATAFRAME

dfmetas.columns =['cdVendedor','data','Meta']

# %%
dfmetas
# Out:
#     cdVendedor                 data           Meta
# 0          102  2017-01-01 00:00:00  140768.312981
# 1          102  2017-02-01 00:00:00  124258.753484
# 2          102  2017-03-01 00:00:00  169509.931262
# 3          102  2017-04-01 00:00:00  143465.231352
# 4          102  2017-05-01 00:00:00   98423.627768
# ..         ...                  ...            ...
# 787        669  2022-08-01 00:00:00          50216
# 788        669  2022-09-01 00:00:00          36746
# 789        669  2022-10-01 00:00:00         136380
# 790        669  2022-11-01 00:00:00          92726
# 791        669  2022-12-01 00:00:00         100680
#
# [792 rows x 3 columns]

# %% [markdown]
# RENOMEAR AS COLUNAS DE TODOS OS DATAFRAMES PARA FICAR MINUSCULO
#
# VERIFICAR OS TIPOS DE DADOS
#
# VERIFICAR SE HÁ DUPLICADAS/INFORMAÇÕES NULAS
#
# VERIFICAR ESTATISTICAS DO DATAFRAME

# %%
df_final.columns = ['dataemissao','datavencimento','nfe','cdcliente','cdvendedor','cdproduto','qtditens','valorunitario','peso liquido']

df_final.info()
df_final.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302840 entries, 0 to 14247
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   dataemissao     302840 non-null  datetime64[ns]
#  1   datavencimento  302840 non-null  datetime64[ns]
#  2   nfe             302840 non-null  int64
#  3   cdcliente       302840 non-null  int64
#  4   cdvendedor      302840 non-null  int64
#  5   cdproduto       302840 non-null  int64
#  6   qtditens        302840 non-null  int64
#  7   valorunitario   302840 non-null  float64
#  8   peso liquido    302840 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(5)
# memory usage: 23.1 MB
#                          dataemissao                 datavencimento  \
# count                         302840                         302840
# mean   2018-08-11 09:49:20.264165632  2018-09-10 07:38:08.574825216
# min              2017-01-12 00:00:00            2017-01-29 00:00:00
# ...

# %%
dfcliente.head()

dfcliente.columns = ['cdcliente','razao social','status','categoria','cidade','uf']

dfcliente.info()

dfcliente.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1411 entries, 0 to 1410
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cdcliente     1411 non-null   int64
#  1   razao social  1411 non-null   object
#  2   status        1411 non-null   object
#  3   categoria     1411 non-null   object
#  4   cidade        1411 non-null   object
#  5   uf            1411 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 66.3+ KB
#           cdcliente
# count  1.411000e+03
# mean   3.864945e+06
# std    1.399728e+06
# min    6.156600e+05
# 25%    2.986102e+06
# 50%    3.849982e+06
# 75%    4.939497e+06
# max    5.808550e+06

# %%
dfproduto.head()

dfproduto.columns = ['cdproduto','descricao','cdgrupo']

dfproduto.info()

dfproduto.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2736 entries, 0 to 2735
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cdproduto  2736 non-null   int64
#  1   descricao  2736 non-null   object
#  2   cdgrupo    2736 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 64.2+ KB
#          cdproduto      cdgrupo
# count  2736.000000  2736.000000
# mean   1368.500000  3066.312500
# std     789.959493  4496.897004
# min       1.000000   102.000000
# 25%     684.750000   110.000000
# 50%    1368.500000   212.000000
# 75%    2052.250000  9999.000000
# max    2736.000000  9999.000000

# %%
dfgrupoproduto.head()

dfgrupoproduto.columns = ['cdgrupo','grupo','linha']

dfgrupoproduto.info()

dfgrupoproduto.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cdgrupo  36 non-null     int64
#  1   grupo    36 non-null     object
#  2   linha    36 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 992.0+ bytes
#            cdgrupo
# count    36.000000
# mean    686.111111
# std    2290.944356
# min     102.000000
# 25%     110.750000
# 50%     125.000000
# 75%     157.000000
# max    9999.000000

# %%
dfvendedor.head()

dfvendedor.columns = ['cdvendedor','vendedor','cdsupervisor','supervisor','cdgerente','gerente','equipe']

dfvendedor.info()

dfvendedor.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cdvendedor    12 non-null     int64
#  1   vendedor      12 non-null     object
#  2   cdsupervisor  12 non-null     int64
#  3   supervisor    12 non-null     object
#  4   cdgerente     12 non-null     int64
#  5   gerente       12 non-null     object
#  6   equipe        12 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 800.0+ bytes
#        cdvendedor  cdsupervisor  cdgerente
# count   12.000000      12.00000  12.000000
# mean   280.333333      35.00000   1.500000
# std    190.782281      13.31438   0.522233
# min    102.000000      15.00000   1.000000
# 25%    173.250000      25.00000   1.000000
# 50%    205.500000      32.50000   1.500000
# 75%    295.250000      40.00000   2.000000
# max    669.000000      55.00000   2.000000

# %%
dfdata.head()

dfdata.columns = ['data','ano','mes','mesnum','dia']

dfdata.info()

dfdata.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    1095 non-null   datetime64[ns]
#  1   ano     1095 non-null   int64
#  2   mes     1095 non-null   object
#  3   mesnum  1095 non-null   int64
#  4   dia     1095 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 42.9+ KB
#                       data         ano       mesnum          dia
# count                 1095  1095.00000  1095.000000  1095.000000
# mean   2018-07-02 00:00:00  2018.00000     6.526027    15.720548
# min    2017-01-01 00:00:00  2017.00000     1.000000     1.000000
# 25%    2017-10-01 12:00:00  2017.00000     4.000000     8.000000
# 50%    2018-07-02 00:00:00  2018.00000     7.000000    16.000000
# 75%    2019-04-01 12:00:00  2019.00000    10.000000    23.000000
# max    2019-12-31 00:00:00  2019.00000    12.000000    31.000000
# ...

# %% [markdown]
# ANÁLISES EXPLORATÓRIAS

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Valor total vendido e Valor total da meta por ano?

df_final['valortotal'] = df_final['qtditens']*df_final['valorunitario']

df_final[['qtditens','valortotal']].sum()

df_result = pd.merge(df_final,                    # TABELA ESQUERDA (PRINCIPAL)
                    dfdata,                       # TABELA DE CONSULTA (DE-PARA)
                    left_on= 'dataemissao',       #COLUNA DA TABELA PRINCIPAL(ID)
                    right_on='data')              #COLUNA DE CONSULTA

df_result
# Out:
#        dataemissao datavencimento      nfe  cdcliente  cdvendedor  cdproduto  \
# 0       2017-01-12     2017-02-22  1492762    3140218         265       1073
# 1       2017-01-12     2017-02-22  1492762    3140218         265       1420
# 2       2017-01-12     2017-02-22  1492762    3140218         265        264
# 3       2017-01-13     2017-01-29  1492719    2983332         265       1154
# 4       2017-01-13     2017-01-29  1492719    2983332         265       1527
# ...            ...            ...      ...        ...         ...        ...
# 260091  2019-03-12     2019-04-14  2173547     673190         265        202
# 260092  2019-03-12     2019-04-14  2173547     673190         265       1154
# 260093  2019-03-12     2019-04-14  2173547     673190         265        668
# 260094  2019-03-12     2019-04-14  2173547     673190         265       1527
# 260095  2019-03-13     2019-04-05  2172961    3771379         215        257
#
# ...
